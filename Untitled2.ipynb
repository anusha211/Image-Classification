# %%
import cv2
import tensorflow as tf
import matplotlib.pyplot as plt

def prepare(filepath):
    IMG_SIZE = 100  
    img_array = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)  # read in the image, convert to grayscale
    new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  # resize image to match model's expected sizing
    return new_array.reshape(-1, IMG_SIZE, IMG_SIZE, 1)

# %%
model = tf.keras.models.load_model("1st-CNN.model")

# %%
a=cv2.imread('test.jpg')
b=cv2.cvtColor(a,cv2.COLOR_BGR2RGB)
plt.imshow(b)
plt.show()

prediction = model.predict([prepare('test.jpg')])
print(prediction)  # will be a list in a list.

if prediction[0][0] == 1:
    ans = ' IT IS BREAD'
elif prediction[0][1] == 1:
    ans = 'IT IS FRENCH_FRIES'
elif prediction[0][2] == 1:
    ans = 'IT IS PIZZA'
print(ans)
# Out:
# [[0. 0. 1.]]
# IT IS PIZZA

# %%
a=cv2.imread('test2.jpg')
b=cv2.cvtColor(a,cv2.COLOR_BGR2RGB)
plt.imshow(b)
plt.show()

prediction = model.predict([prepare('test2.jpg')])
print(prediction)  # will be a list in a list.

if prediction[0][0] == 1:
    ans = ' IT IS BREAD'
elif prediction[0][1] == 1:
    ans = 'IT IS FRENCH_FRIES'
elif prediction[0][2] == 1:
    ans = 'IT IS PIZZA'
print(ans)
# Out:
# [[0. 0. 1.]]
# IT IS PIZZA

# %%
a=cv2.imread('test8.jpg')
b=cv2.cvtColor(a,cv2.COLOR_BGR2RGB)
plt.imshow(b)
plt.show()

prediction = model.predict([prepare('test8.jpg')])
print(prediction)  # will be a list in a list.

if prediction[0][0] == 1:
    ans = ' IT IS BREAD'
elif prediction[0][1] == 1:
    ans = 'IT IS FRENCH_FRIES'
elif prediction[0][2] == 1:
    ans = 'IT IS PIZZA'
print(ans)
# Out:
# [[0. 1. 0.]]
# IT IS FRENCH_FRIES

# %%
a=cv2.imread('test7.jpg')
b=cv2.cvtColor(a,cv2.COLOR_BGR2RGB)
plt.imshow(b)
plt.show()

prediction = model.predict([prepare('test7.jpg')])
print(prediction)  # will be a list in a list.

if prediction[0][0] == 1:
    ans = ' IT IS BREAD'
elif prediction[0][1] == 1:
    ans = 'IT IS FRENCH_FRIES'
elif prediction[0][2] == 1:
    ans = 'IT IS PIZZA'
print(ans)
# Out:
# [[0. 0. 1.]]
# IT IS PIZZA

# %%
a=cv2.imread('test9.jpg')
b=cv2.cvtColor(a,cv2.COLOR_BGR2RGB)
plt.imshow(b)
plt.show()

prediction = model.predict([prepare('test9.jpg')])
print(prediction)  # will be a list in a list.

if prediction[0][0] == 1:
    ans = ' IT IS BREAD'
elif prediction[0][1] == 1:
    ans = 'IT IS FRENCH_FRIES'
elif prediction[0][2] == 1:
    ans = 'IT IS PIZZA'
print(ans)
# Out:
# [[0. 0. 1.]]
# IT IS PIZZA

# %%
a=cv2.imread('test10.jpg')
b=cv2.cvtColor(a,cv2.COLOR_BGR2RGB)
plt.imshow(b)
plt.show()

prediction = model.predict([prepare('test10.jpg')])
print(prediction)  # will be a list in a list.

if prediction[0][0] == 1:
    ans = ' IT IS BREAD'
elif prediction[0][1] == 1:
    ans = 'IT IS FRENCH_FRIES'
elif prediction[0][2] == 1:
    ans = 'IT IS PIZZA'
print(ans)
# Out:
# [[0. 0. 1.]]
# IT IS PIZZA

# %%
a=cv2.imread('test11.jpg')
b=cv2.cvtColor(a,cv2.COLOR_BGR2RGB)
plt.imshow(b)
plt.show()

prediction = model.predict([prepare('test11.jpg')])
print(prediction)  # will be a list in a list.

if prediction[0][0] == 1:
    ans = ' IT IS BREAD'
elif prediction[0][1] == 1:
    ans = 'IT IS FRENCH_FRIES'
elif prediction[0][2] == 1:
    ans = 'IT IS PIZZA'
print(ans)
# Out:
# [[0. 0. 1.]]
# IT IS PIZZA

# %%
a=cv2.imread('test1.jpg')
b=cv2.cvtColor(a,cv2.COLOR_BGR2RGB)
plt.imshow(b)
plt.show()

prediction = model.predict([prepare('test1.jpg')])
print(prediction)  # will be a list in a list.

if prediction[0][0] == 1:
    ans = ' IT IS BREAD'
elif prediction[0][1] == 1:
    ans = 'IT IS FRENCH_FRIES'
elif prediction[0][2] == 1:
    ans = 'IT IS PIZZA'
print(ans)
# Out:
# [[0. 0. 1.]]
# IT IS PIZZA

# %%
a=cv2.imread('test4.jpg')
b=cv2.cvtColor(a,cv2.COLOR_BGR2RGB)
plt.imshow(b)
plt.show()

prediction = model.predict([prepare('test4.jpg')])
print(prediction)  # will be a list in a list.

if prediction[0][0] == 1:
    ans = ' IT IS BREAD'
elif prediction[0][1] == 1:
    ans = 'IT IS FRENCH_FRIES'
elif prediction[0][2] == 1:
    ans = 'IT IS PIZZA'
print(ans)
# Out:
# [[0. 0. 1.]]
# IT IS PIZZA

# %%
a=cv2.imread('test9.jpg')
b=cv2.cvtColor(a,cv2.COLOR_BGR2RGB)
plt.imshow(b)
plt.show()

prediction = model.predict([prepare('test9.jpg')])
print(prediction)  # will be a list in a list.

if prediction[0][0] == 1:
    ans = ' IT IS BREAD'
elif prediction[0][1] == 1:
    ans = 'IT IS FRENCH_FRIES'
elif prediction[0][2] == 1:
    ans = 'IT IS PIZZA'
print(ans)
# Out:
# [[0. 0. 1.]]
# IT IS PIZZA

# %%
a=cv2.imread('test8.jpg')
b=cv2.cvtColor(a,cv2.COLOR_BGR2RGB)
plt.imshow(b)
plt.show()

prediction = model.predict([prepare('test8.jpg')])
print(prediction)  # will be a list in a list.

if prediction[0][0] == 1:
    ans = ' IT IS BREAD'
elif prediction[0][1] == 1:
    ans = 'IT IS FRENCH_FRIES'
elif prediction[0][2] == 1:
    ans = 'IT IS PIZZA'
print(ans)
# Out:
# [[0. 1. 0.]]
# IT IS FRENCH_FRIES

# %%
a=cv2.imread('test10.jpg')
b=cv2.cvtColor(a,cv2.COLOR_BGR2RGB)
plt.imshow(b)
plt.show()

prediction = model.predict([prepare('test10.jpg')])
print(prediction)  # will be a list in a list.

if prediction[0][0] == 1:
    ans = ' IT IS BREAD'
elif prediction[0][1] == 1:
    ans = 'IT IS FRENCH_FRIES'
elif prediction[0][2] == 1:
    ans = 'IT IS PIZZA'
print(ans)
# Out:
# [[0. 0. 1.]]
# IT IS PIZZA

# %%
a=cv2.imread('test9.jpg')
b=cv2.cvtColor(a,cv2.COLOR_BGR2RGB)
plt.imshow(b)
plt.show()

prediction = model.predict([prepare('test9.jpg')])
print(prediction)  # will be a list in a list.

if prediction[0][0] == 1:
    ans = ' IT IS BREAD'
elif prediction[0][1] == 1:
    ans = 'IT IS FRENCH_FRIES'
elif prediction[0][2] == 1:
    ans = 'IT IS PIZZA'
print(ans)
# Out:
# [[0. 0. 1.]]
# IT IS PIZZA

# %%
a=cv2.imread('test9.jpg')
b=cv2.cvtColor(a,cv2.COLOR_BGR2RGB)
plt.imshow(b)
plt.show()

prediction = model.predict([prepare('test9.jpg')])
print(prediction)  # will be a list in a list.

if prediction[0][0] == 1:
    ans = ' IT IS BREAD'
elif prediction[0][1] == 1:
    ans = 'IT IS FRENCH_FRIES'
elif prediction[0][2] == 1:
    ans = 'IT IS PIZZA'
print(ans)
# Out:
# [[0. 0. 1.]]
# IT IS PIZZA

# %%
a=cv2.imread('test5.jpg')
b=cv2.cvtColor(a,cv2.COLOR_BGR2RGB)
plt.imshow(b)
plt.show()

prediction = model.predict([prepare('test5.jpg')])
print(prediction)  # will be a list in a list.

if prediction[0][0] == 1:
    ans = ' IT IS BREAD'
elif prediction[0][1] == 1:
    ans = 'IT IS FRENCH_FRIES'
elif prediction[0][2] == 1:
    ans = 'IT IS PIZZA'
print(ans)
# Out:
# [[0.0000000e+00 1.7794935e-29 1.0000000e+00]]
# IT IS PIZZA

# %%
a=cv2.imread('test7.jpg')
b=cv2.cvtColor(a,cv2.COLOR_BGR2RGB)
plt.imshow(b)
plt.show()

prediction = model.predict([prepare('test7.jpg')])
print(prediction)  # will be a list in a list.

if prediction[0][0] == 1:
    ans = ' IT IS BREAD'
elif prediction[0][1] == 1:
    ans = 'IT IS FRENCH_FRIES'
elif prediction[0][2] == 1:
    ans = 'IT IS PIZZA'
print(ans)
